# %% [markdown]
# done

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %% [markdown]
# The goal here is to find the accuracy of the Logistic Regression Model when working without Elo Ratings as a feature. So first we need to load the data from the cleaned handled data with elo ratings. We will also have to implement feature engineering for differences between player1 and player2 aspects.

# %%
modelLR_df = pd.read_csv("atp_matches_2010_2024_missing_handled.csv")

# %%
modelLR_df.head() # verification
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0   2010-339     Brisbane    Hard         32             A      20100103
# 1   2010-339     Brisbane    Hard         32             A      20100103
# 2   2010-339     Brisbane    Hard         32             A      20100103
# 3   2010-339     Brisbane    Hard         32             A      20100103
# 4   2010-339     Brisbane    Hard         32             A      20100103
#
#    match_num  winner_id     winner_name winner_hand  ...  l_1stIn l_1stWon  \
# 0          1     104053    Andy Roddick           R  ...     34.0     29.0
# 1         30     103285  Radek Stepanek           R  ...     27.0     14.0
# 2         29     104053    Andy Roddick           R  ...     43.0     34.0
# 3         28     103285  Radek Stepanek           R  ...     40.0     25.0
# 4         27     104792    Gael Monfils           R  ...     50.0     38.0
#
#    l_2ndWon  l_SvGms l_bpSaved l_bpFaced  winner_rank winner_rank_points  \
# ...

# %% [markdown]
# aspects that need to be feature_engineered:
#
# rank_diff = winner_rank - loser_rank
#
# ace_diff = w_ace - l_ace
#
# df_diff = w_df - l_df
#
# svpt_diff = w_svpt - l_svpt
#
# 1stIn_diff = w_1stIn - l_1stIn
#
# 1stWon_diff = w_1stWon - l_1stWon
#
# 2ndWon_diff = w_2ndWon - l_2ndWon
#
# SvGms_diff = w_SvGms - l_SvGms
#
# bpSaved_diff = w_bpSaved - l_bpSaved
#
# bpFaced_diff = w_bpFaced - l_bpFaced
#
# age_diff = winner_age - loser_age

# %%
modelLR_df["rank_diff"] = modelLR_df["winner_rank"] - modelLR_df["loser_rank"]
modelLR_df["ace_diff"] = modelLR_df["w_ace"] - modelLR_df["l_ace"]
modelLR_df["df_diff"] = modelLR_df["w_df"] - modelLR_df["l_df"]
#modelLR_df["svpt_diff"] = modelLR_df["w_svpt"] - modelLR_df["l_svpt"]
modelLR_df["1stIn_diff"] = modelLR_df["w_1stIn"] - modelLR_df["l_1stIn"]
modelLR_df["1stWon_diff"] = modelLR_df["w_1stWon"] - modelLR_df["l_1stWon"]
#modelLR_df["2ndWon_diff"] = modelLR_df["w_2ndWon"] - modelLR_df["l_2ndWon"]
modelLR_df["SvGms_diff"] = modelLR_df["w_SvGms"] - modelLR_df["l_SvGms"]
modelLR_df["bpSaved_diff"] = modelLR_df["w_bpSaved"] - modelLR_df["l_bpSaved"]
modelLR_df["bpFaced_diff"] = modelLR_df["w_bpFaced"] - modelLR_df["l_bpFaced"]
modelLR_df["age_diff"] = modelLR_df["winner_age"] - modelLR_df["loser_age"]

# %%
modelLR_df.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0   2010-339     Brisbane    Hard         32             A      20100103
# 1   2010-339     Brisbane    Hard         32             A      20100103
# 2   2010-339     Brisbane    Hard         32             A      20100103
# 3   2010-339     Brisbane    Hard         32             A      20100103
# 4   2010-339     Brisbane    Hard         32             A      20100103
#
#    match_num  winner_id     winner_name winner_hand  ...  loser_rank_points  \
# 0          1     104053    Andy Roddick           R  ...              598.0
# 1         30     103285  Radek Stepanek           R  ...             2610.0
# 2         29     104053    Andy Roddick           R  ...             1655.0
# 3         28     103285  Radek Stepanek           R  ...              521.0
# 4         27     104792    Gael Monfils           R  ...              935.0
#
#   rank_diff  ace_diff  df_diff 1stIn_diff 1stWon_diff  SvGms_diff  \
# ...

# %%
# Encode categorical variable: surface
modelLR_df = pd.get_dummies(modelLR_df, columns=["surface"], drop_first=True)

# Convert bool to int for one-hot encoded columns
for col in ["surface_Grass", "surface_Hard"]:
    modelLR_df[col] = modelLR_df[col].astype(int)

# %%
# Features to use
feature_cols = [
    "ace_diff", "df_diff", "1stIn_diff", "SvGms_diff", "age_diff", "1stWon_diff", 
      "bpSaved_diff", "bpFaced_diff",  "rank_diff",
    "surface_Grass",  "surface_Hard"  # Assuming Clay is the reference
]
#"2ndWon_diff", "svpt_diff",

# %% [markdown]
# Debugging/Verification methods

# %%
print("Data types of features:")
print(modelLR_df[feature_cols].dtypes)
print("\nNaN check in features:")
print(modelLR_df[feature_cols].isna().sum())
# Out:
# Data types of features:
# ace_diff         float64
# df_diff          float64
# 1stIn_diff       float64
# SvGms_diff       float64
# age_diff         float64
# 1stWon_diff      float64
# bpSaved_diff     float64
# bpFaced_diff     float64
# rank_diff        float64
# surface_Grass      int64
# surface_Hard       int64
# dtype: object
#
# NaN check in features:
# ace_diff         0
# df_diff          0
# 1stIn_diff       0
# SvGms_diff       0
# age_diff         0
# 1stWon_diff      0
# bpSaved_diff     0
# bpFaced_diff     0
# rank_diff        0
# surface_Grass    0
# surface_Hard     0
# dtype: int64

# %%
# Target: 1 if winner is Player A (recorded winner), 0 if loser wins (flip for symmetry later)
modelLR_df["target"] = 1

# %%
# Create a symmetric dataset by flipping winner/loser
df_flipped = modelLR_df.copy()

df_flipped["rank_diff"] = -df_flipped["rank_diff"]
df_flipped["ace_diff"] = -df_flipped["ace_diff"]
df_flipped["df_diff"] = -df_flipped["df_diff"]
#df_flipped["svpt_diff"] = -df_flipped["svpt_diff"]
df_flipped["1stIn_diff"] = -df_flipped["1stIn_diff"]
df_flipped["1stWon_diff"] = -df_flipped["1stWon_diff"]
#df_flipped["2ndWon_diff"] = -df_flipped["2ndWon_diff"]
df_flipped["SvGms_diff"] = -df_flipped["SvGms_diff"]
df_flipped["bpSaved_diff"] = -df_flipped["bpSaved_diff"]
df_flipped["bpFaced_diff"] = -df_flipped["bpFaced_diff"]
df_flipped["age_diff"] = -df_flipped["age_diff"]
df_flipped["target"] = 0

# %%
# Combine original and flipped data
df_symmetric = pd.concat([modelLR_df, df_flipped], ignore_index=True)

# %%
# Step 2: Train-Test Split
df_symmetric["tourney_date"] = pd.to_datetime(df_symmetric["tourney_date"], format="%Y%m%d", errors="coerce")
df_symmetric = df_symmetric.dropna(subset=["tourney_date"])
df_symmetric["year"] = df_symmetric["tourney_date"].dt.year
train_data = df_symmetric[df_symmetric["year"] <= 2022]
test_data = df_symmetric[df_symmetric["year"] > 2022]

X_train = train_data[feature_cols].values
y_train = train_data["target"].values
X_test = test_data[feature_cols].values
y_test = test_data["target"].values

# Debug: Check array shape and type
print("\nX_train shape:", X_train.shape)
print("X_train dtype:", X_train.dtype)
print("X_test shape: ", X_test.shape)
# Out:
# X_train shape: (73010, 11)
# X_train dtype: float64
# X_test shape:  (12018, 11)

# %%
df_symmetric.head()
# Out:
#   tourney_id tourney_name  draw_size tourney_level tourney_date  match_num  \
# 0   2010-339     Brisbane         32             A   2010-01-03          1
# 1   2010-339     Brisbane         32             A   2010-01-03         30
# 2   2010-339     Brisbane         32             A   2010-01-03         29
# 3   2010-339     Brisbane         32             A   2010-01-03         28
# 4   2010-339     Brisbane         32             A   2010-01-03         27
#
#    winner_id     winner_name winner_hand  winner_ht  ... 1stWon_diff  \
# 0     104053    Andy Roddick           R      188.0  ...         7.0
# 1     103285  Radek Stepanek           R      185.0  ...         6.0
# 2     104053    Andy Roddick           R      188.0  ...         9.0
# 3     103285  Radek Stepanek           R      185.0  ...        -1.0
# 4     104792    Gael Monfils           R      193.0  ...         3.0
#
#    SvGms_diff  bpSaved_diff bpFaced_diff age_diff  surface_Clay surface_Grass  \
# ...

# %%
df_symmetric.tail()
# Out:
#       tourney_id     tourney_name  draw_size tourney_level tourney_date  \
# 85023  2024-7696  Next Gen Finals          8             F   2024-12-18
# 85024  2024-7696  Next Gen Finals          8             F   2024-12-18
# 85025  2024-7696  Next Gen Finals          8             F   2024-12-18
# 85026  2024-7696  Next Gen Finals          8             F   2024-12-18
# 85027  2024-7696  Next Gen Finals          8             F   2024-12-18
#
#        match_num  winner_id          winner_name winner_hand  winner_ht  ...  \
# 85023        387     210460  Nishesh Basavareddy           R      180.0  ...
# 85024        388     209414      Luca Van Assche           R      178.0  ...
# 85025        389     210506       Alex Michelsen           R      193.0  ...
# 85026        391     210506       Alex Michelsen           R      193.0  ...
# 85027        395     211663         Joao Fonseca           R      185.0  ...
#
#       1stWon_diff  SvGms_diff  bpSaved_diff bpFaced_diff age_diff  \
# ...

# %%
# Step 3: Normalize features
X_train_mean = np.nanmean(X_train, axis=0)
X_train_std = np.nanstd(X_train, axis=0)
X_train_std[X_train_std == 0] = 1e-10  # Avoid division by zero with small epsilon
X_train = np.where(np.isnan(X_train), 0, X_train)
X_train = (X_train - X_train_mean) / X_train_std
X_test = np.where(np.isnan(X_test), 0, X_test)
X_test = (X_test - X_train_mean) / X_train_std

# %%
# Add intercept term
X_train = np.hstack([np.ones((X_train.shape[0], 1)), X_train])
X_test = np.hstack([np.ones((X_test.shape[0], 1)), X_test])

# %%
# Step 4: Implement Logistic Regression
def sigmoid(z):
    return 1 / (1 + np.exp(-np.clip(z, -500, 500)))  # Clip to avoid overflow

def compute_loss(X, y, beta):
    z = np.dot(X, beta)
    y_pred = sigmoid(z)
    loss = -np.mean(y * np.log(y_pred + 1e-10) + (1 - y) * np.log(1 - y_pred + 1e-10))
    return loss

def compute_gradient(X, y, beta):
    z = np.dot(X, beta)
    y_pred = sigmoid(z)
    gradient = np.dot(X.T, (y_pred - y)) / len(y)
    return gradient

# Gradient Descent
beta = np.zeros(X_train.shape[1])  # Initialize coefficients
learning_rate = 0.01
n_iterations = 5000

for i in range(n_iterations):
    gradient = compute_gradient(X_train, y_train, beta)
    beta -= learning_rate * gradient
    if i % 100 == 0:
        loss = compute_loss(X_train, y_train, beta)
        print(f"Iteration {i}, Loss: {loss:.4f}")
# Out:
# Iteration 0, Loss: 0.6909
# Iteration 100, Loss: 0.5440
# Iteration 200, Loss: 0.4786
# Iteration 300, Loss: 0.4425
# Iteration 400, Loss: 0.4195
# Iteration 500, Loss: 0.4032
# Iteration 600, Loss: 0.3909
# Iteration 700, Loss: 0.3810
# Iteration 800, Loss: 0.3728
# Iteration 900, Loss: 0.3658
# Iteration 1000, Loss: 0.3596
# Iteration 1100, Loss: 0.3542
# Iteration 1200, Loss: 0.3492
# Iteration 1300, Loss: 0.3447
# Iteration 1400, Loss: 0.3405
# Iteration 1500, Loss: 0.3366
# Iteration 1600, Loss: 0.3329
# Iteration 1700, Loss: 0.3295
# Iteration 1800, Loss: 0.3262
# Iteration 1900, Loss: 0.3232
# Iteration 2000, Loss: 0.3202
# Iteration 2100, Loss: 0.3175
# Iteration 2200, Loss: 0.3148
# Iteration 2300, Loss: 0.3123
# Iteration 2400, Loss: 0.3098
# Iteration 2500, Loss: 0.3075
# Iteration 2600, Loss: 0.3053
# Iteration 2700, Loss: 0.3031
# Iteration 2800, Loss: 0.3011
# Iteration 2900, Loss: 0.2991
# Iteration 3000, Loss: 0.2971
# Iteration 3100, Loss: 0.2953
# ...

# %%
# Step 5: Predict and Evaluate
def predict(X, beta):
    z = np.dot(X, beta)
    y_pred = sigmoid(z)
    return (y_pred >= 0.5).astype(int)

# Training accuracy
y_train_pred = predict(X_train, beta)
train_accuracy = np.mean(y_train_pred == y_train)
print(f"\nTraining Accuracy: {train_accuracy:.2%}")

# Test accuracy
y_test_pred = predict(X_test, beta)
test_accuracy = np.mean(y_test_pred == y_test)
print(f"Test Accuracy: {test_accuracy:.2%}")
# Out:
# Training Accuracy: 89.83%
# Test Accuracy: 89.68%

# %%
from sklearn.metrics import accuracy_score, classification_report

# Predictions
y_train_pred = predict(X_train, beta)
y_test_pred = predict(X_test, beta)

# Accuracy using sklearn
train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

print(f"Training Accuracy: {train_accuracy:.2%}")
print(f"Test Accuracy: {test_accuracy:.2%}")

# Detailed Classification Report
print("\nClassification Report (Test Set):")
print(classification_report(y_test, y_test_pred, target_names=["Player B Win", "Player A Win"]))
# Out:
# Training Accuracy: 89.83%
# Test Accuracy: 89.68%
#
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
# Player B Win       0.90      0.90      0.90      6009
# Player A Win       0.90      0.90      0.90      6009
#
#     accuracy                           0.90     12018
#    macro avg       0.90      0.90      0.90     12018
# weighted avg       0.90      0.90      0.90     12018

# %%
import pandas as pd
coef_df = pd.DataFrame({'feature': feature_cols, 'coefficient': beta[1:]})
coef_df['abs_coef'] = coef_df['coefficient'].abs()
coef_df = coef_df.sort_values(by='abs_coef', ascending=False)
print(coef_df)
# Out:
#           feature   coefficient      abs_coef
# 7    bpFaced_diff -2.103278e+00  2.103278e+00
# 5     1stWon_diff  1.697418e+00  1.697418e+00
# 2      1stIn_diff -9.661253e-01  9.661253e-01
# 6    bpSaved_diff  9.100109e-01  9.100109e-01
# 3      SvGms_diff  4.372175e-01  4.372175e-01
# 8       rank_diff -3.637619e-01  3.637619e-01
# 1         df_diff -3.258760e-01  3.258760e-01
# 0        ace_diff  9.022156e-02  9.022156e-02
# 4        age_diff -1.999894e-02  1.999894e-02
# 9   surface_Grass  7.586195e-19  7.586195e-19
# 10   surface_Hard  7.393985e-19  7.393985e-19

# %%
odds_ratios = np.exp(beta[1:])
odds_df = pd.DataFrame({'feature': feature_cols, 'odds_ratio': odds_ratios})
odds_df = odds_df.sort_values(by='odds_ratio', ascending=False)
print(odds_df)
# Out:
#           feature  odds_ratio
# 5     1stWon_diff    5.459831
# 6    bpSaved_diff    2.484350
# 3      SvGms_diff    1.548393
# 0        ace_diff    1.094417
# 9   surface_Grass    1.000000
# 10   surface_Hard    1.000000
# 4        age_diff    0.980200
# 1         df_diff    0.721895
# 8       rank_diff    0.695057
# 2      1stIn_diff    0.380555
# 7    bpFaced_diff    0.122056

# %%
import statsmodels.api as sm
logit_model = sm.Logit(y_train, X_train)
result = logit_model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.180589
#          Iterations 9
#                            Logit Regression Results
# ...
# Dep. Variable:                      y   No. Observations:                73010
# Model:                          Logit   Df Residuals:                    72998
# Method:                           MLE   Df Model:                           11
# Date:                Sun, 04 May 2025   Pseudo R-squ.:                  0.7395
# Time:                        17:33:36   Log-Likelihood:                -13185.
# converged:                       True   LL-Null:                       -50607.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.333e-16      0.016   8.46e-15      1.000      -0.031       0.031
# ...

# %%
import tkinter as tk
from tkinter import ttk
import numpy as np

# ---------------------------
# Assumptions:
# The following variables/functions are assumed to be defined from your model training:
# beta, X_train_mean, X_train_std, and predict
#
# Example placeholder definitions (remove these if you already have them):
# def sigmoid(z):
#     return 1 / (1 + np.exp(-np.clip(z, -500, 500)))
#
# def predict(X, beta):
#     z = np.dot(X, beta)
#     y_pred = sigmoid(z)
#     return (y_pred >= 0.5).astype(int)
#
# beta = np.array([...])  # Your trained coefficients
# X_train_mean = np.array([...])  # Training mean computed earlier
# X_train_std = np.array([...])   # Training std computed earlier
# ---------------------------

def predict_proba(X, beta):
    z = np.dot(X, beta)
    y_pred = sigmoid(z)
    # Return probabilities for class 0 and class 1:
    return np.column_stack([1 - y_pred, y_pred])

def predict_outcome():
    try:
        # --- Read Player 1 stats ---
        p1_ace = float(entry_p1_ace.get())
        p1_df = float(entry_p1_df.get())
        p1_1stIn = float(entry_p1_1stIn.get())
        p1_SvGms = float(entry_p1_SvGms.get())
        p1_age = float(entry_p1_age.get())
        p1_1stWon = float(entry_p1_1stWon.get())
        #p1_2ndWon = float(entry_p1_2ndWon.get())
        p1_bpSaved = float(entry_p1_bpSaved.get())
        p1_bpFaced = float(entry_p1_bpFaced.get())
        #p1_svpt = float(entry_p1_svpt.get())
        p1_rank = float(entry_p1_rank.get())
        
        # --- Read Player 2 stats ---
        p2_ace = float(entry_p2_ace.get())
        p2_df = float(entry_p2_df.get())
        p2_1stIn = float(entry_p2_1stIn.get())
        p2_SvGms = float(entry_p2_SvGms.get())
        p2_age = float(entry_p2_age.get())
        p2_1stWon = float(entry_p2_1stWon.get())
        #p2_2ndWon = float(entry_p2_2ndWon.get())
        p2_bpSaved = float(entry_p2_bpSaved.get())
        p2_bpFaced = float(entry_p2_bpFaced.get())
        #p2_svpt = float(entry_p2_svpt.get())
        p2_rank = float(entry_p2_rank.get())
        
        # --- Compute differences (Player 1 - Player 2) ---
        ace_diff = p1_ace - p2_ace
        df_diff = p1_df - p2_df
        firstIn_diff = p1_1stIn - p2_1stIn
        SvGms_diff = p1_SvGms - p2_SvGms
        age_diff = p1_age - p2_age
        firstWon_diff = p1_1stWon - p2_1stWon
        #secondWon_diff = p1_2ndWon - p2_2ndWon
        bpSaved_diff = p1_bpSaved - p2_bpSaved
        bpFaced_diff = p1_bpFaced - p2_bpFaced
        #svpt_diff = p1_svpt - p2_svpt
        rank_diff = p1_rank - p2_rank
        
        # --- Surface selection (dropdown) ---
        surface = surface_var.get()
        if surface == "Grass":
            surface_Grass = 1
            surface_Hard = 0
        elif surface == "Hard":
            surface_Grass = 0
            surface_Hard = 1
        else:  # Clay (reference)
            surface_Grass = 0
            surface_Hard = 0
        
        # --- Create feature vector in the same order as used for training ---
        features = np.array([[ace_diff, 
                              df_diff, 
                              firstIn_diff, 
                              SvGms_diff, 
                              age_diff,
                              firstWon_diff, 
                              #secondWon_diff, 
                              bpSaved_diff, 
                              bpFaced_diff,
                              #svpt_diff, 
                              rank_diff, 
                              surface_Grass,  
                              surface_Hard]])
        
        # --- Normalize the new datapoint using training data's mean and std ---
        features_norm = (features - X_train_mean) / X_train_std
        
        # --- Add intercept term ---
        features_norm = np.hstack([np.ones((features_norm.shape[0], 1)), features_norm])
        
        # --- Predict outcome ---
        pred = predict(features_norm, beta)
        probs = predict_proba(features_norm, beta)
        outcome = "Player 1 wins" if pred[0] == 1 else "Player 2 wins"
        prob_text = f"Probabilities:\nPlayer 2 Win: {probs[0,0]*100:.2f}%\nPlayer 1 Win: {probs[0,1]*100:.2f}%"
        result_label.config(text=f"Predicted Outcome: {outcome}\n{prob_text}")
    except Exception as e:
        result_label.config(text=f"Error: {e}")

# --- Create the main Tkinter window ---
root = tk.Tk()
root.title("Tennis Match Outcome Predictor")

# --- Frame for Player 1 Inputs ---
frame_p1 = tk.LabelFrame(root, text="Player 1 Stats")
frame_p1.grid(row=0, column=0, padx=10, pady=10, sticky="nsew")

# --- Frame for Player 2 Inputs ---
frame_p2 = tk.LabelFrame(root, text="Player 2 Stats")
frame_p2.grid(row=0, column=1, padx=10, pady=10, sticky="nsew")

# --- Define the list of stats (same order as used in feature engineering) ---
stats = [
    ("ace", "Aces"),
    ("df", "Double Faults"),
    ("1stIn", "1st In"),
    ("SvGms", "Service Games"),
    ("age", "Age"),
    ("1stWon", "1st Won"),
    ("bpSaved", "Break Points Saved"),
    ("bpFaced", "Break Points Faced"),
    ("rank", "Rank")
    #("svpt", "Serve Points"),
    #("2ndWon", "2nd Won"),
]

entries_p1 = {}
entries_p2 = {}

# --- Create labels and entry fields for each stat for both players ---
for i, (key, label_text) in enumerate(stats):
    # Player 1
    tk.Label(frame_p1, text=label_text).grid(row=i, column=0, sticky="w", padx=5, pady=2)
    entries_p1[key] = tk.Entry(frame_p1)
    entries_p1[key].grid(row=i, column=1, padx=5, pady=2)
    
    # Player 2
    tk.Label(frame_p2, text=label_text).grid(row=i, column=0, sticky="w", padx=5, pady=2)
    entries_p2[key] = tk.Entry(frame_p2)
    entries_p2[key].grid(row=i, column=1, padx=5, pady=2)

# --- Assign entry widgets to variables for easier access ---
entry_p1_ace    = entries_p1["ace"]
entry_p1_df     = entries_p1["df"]
entry_p1_1stIn  = entries_p1["1stIn"]
entry_p1_SvGms  = entries_p1["SvGms"]
entry_p1_age    = entries_p1["age"]
entry_p1_1stWon = entries_p1["1stWon"]
#entry_p1_2ndWon = entries_p1["2ndWon"]
entry_p1_bpSaved= entries_p1["bpSaved"]
entry_p1_bpFaced= entries_p1["bpFaced"]
#entry_p1_svpt   = entries_p1["svpt"]
entry_p1_rank   = entries_p1["rank"]

entry_p2_ace    = entries_p2["ace"]
entry_p2_df     = entries_p2["df"]
entry_p2_1stIn  = entries_p2["1stIn"]
entry_p2_SvGms  = entries_p2["SvGms"]
entry_p2_age    = entries_p2["age"]
entry_p2_1stWon = entries_p2["1stWon"]
#entry_p2_2ndWon = entries_p2["2ndWon"]
entry_p2_bpSaved= entries_p2["bpSaved"]
entry_p2_bpFaced= entries_p2["bpFaced"]
#entry_p2_svpt   = entries_p2["svpt"]
entry_p2_rank   = entries_p2["rank"]

# --- Surface Selection Dropdown ---
tk.Label(root, text="Select Surface:").grid(row=1, column=0, padx=10, sticky="w")
surface_var = tk.StringVar(root)
surface_var.set("Clay")  # default selection
surface_menu = tk.OptionMenu(root, surface_var, "Clay", "Grass", "Hard")
surface_menu.grid(row=1, column=1, padx=10, sticky="w")

# --- Predict Button ---
predict_button = tk.Button(root, text="Predict Outcome", command=predict_outcome)
predict_button.grid(row=2, column=0, columnspan=2, pady=10)

# --- Label to Display the Result ---
result_label = tk.Label(root, text="Predicted Outcome: ")
result_label.grid(row=3, column=0, columnspan=2, pady=10)

# --- Run the GUI main loop ---
root.mainloop()
# Out:
# 2025-05-04 17:33:47.179 Python[38729:27654990] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-05-04 17:33:47.179 Python[38729:27654990] +[IMKInputSession subclass]: chose IMKInputSession_Modern
